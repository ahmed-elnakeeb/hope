# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.0'

# %%
mnist=tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()

# %%
fashion=tf.keras.datasets.fashion_mnist
(x_train,y_train),(x_test,y_test)=fashion.load_data()
print(y_test)
# Out:
# [9 2 1 ... 8 1 5]

# %%
cloth={
0:	"T-shirt/top"
,1:	"Trouser"
,2:	"Pullover"
,3:	"Dress"
,4:	"Coat"
,5:	"Sandal"
,6:	"Shirt"
,7:	"Sneaker"
,8:	"Bag"
,9:	"Ankle boot"
}

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[0],cmap=plt.cm.binary)
plt.show()

# %%
x_train=tf.keras.utils.normalize(x_train,axis=1)
x_test=tf.keras.utils.normalize(x_test,axis=1)
fashion=tf.keras.models.Sequential()
fashion.add(tf.keras.layers.Flatten())
fashion.add(tf.keras.layers.Dense(265,activation=tf.nn.relu))
fashion.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
fashion.add(tf.keras.layers.Dense(64,activation=tf.nn.relu))
fashion.add(tf.keras.layers.Dense(32,activation=tf.nn.relu))

fashion.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))
fashion.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
fashion.fit(x_train,y_train,epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4978 - accuracy: 0.8171
# Epoch 2/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3617 - accuracy: 0.8662
# Epoch 3/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3260 - accuracy: 0.8782
# Epoch 4/20
# 1875/1875 [==============================] - 2s 983us/step - loss: 0.3015 - accuracy: 0.8880
# Epoch 5/20
# 1875/1875 [==============================] - 2s 993us/step - loss: 0.2822 - accuracy: 0.8941
# Epoch 6/20
# 1875/1875 [==============================] - 2s 996us/step - loss: 0.2667 - accuracy: 0.9001
# Epoch 7/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2519 - accuracy: 0.9052
# Epoch 8/20
# 1875/1875 [==============================] - 2s 987us/step - loss: 0.2403 - accuracy: 0.9083
# Epoch 9/20
# 1875/1875 [==============================] - 2s 987us/step - loss: 0.2290 - accuracy: 0.9146
# Epoch 10/20
# 1875/1875 [==============================] - 2s 990us/step - loss: 0.2213 - accuracy: 0.9153
# Epoch 11/20
# 1875/1875 [==============================] - 2s 974us/step - loss: 0.2107 - accuracy: 0.9203
# Epoch 12/20
# 1875/1875 [==============================] - 2s 977us/step - loss: 0.2042 - accuracy: 0.9227
# Epoch 13/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1950 - accuracy: 0.9258
# Epoch 14/20
# 1875/1875 [==============================] - 2s 995us/step - loss: 0.1884 - accuracy: 0.9285
# Epoch 15/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1810 - accuracy: 0.9315
# Epoch 16/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1771 - accuracy: 0.9332
# Epoch 17/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1682 - accuracy: 0.9366
# Epoch 18/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1650 - accuracy: 0.9373
# Epoch 19/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1587 - accuracy: 0.9388
# Epoch 20/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1533 - accuracy: 0.9416

# %%
val_loss,val_acc=model.evaluate(x_test,y_test)
print("loss= ",val_loss,"\nacc= ",val_acc)
# Out:
# 313/313 [==============================] - 0s 530us/step - loss: 0.1536 - accuracy: 0.9750
# loss=  0.15363381803035736
# acc=  0.9750000238418579

# %%
#fashion.save("fashion.model")
#tf.keras.models.save_model(fashion,"fashion.model")

fashion=tf.keras.models.load_model("fashion")

# %%
import numpy as np
fashion=tf.keras.models.load_model("fashion")

predections=fashion.predict([x_test])
print(np.argmax(predections[10]))
plt.imshow(x_test[10],cmap=plt.cm.binary)
print(y_test[10],cloth[y_test[10]])
plt.show()
# Out:
# 4
# 4 Coat

# %%
#print(predections)
# Out:
# [[4.1366821e-10 7.8875945e-10 1.2940258e-06 ... 9.9999630e-01
#   8.5061364e-10 2.8401137e-08]
#  [1.0917943e-10 9.8516523e-08 9.9999988e-01 ... 4.0690829e-11
#   2.3996866e-10 9.8353908e-16]
#  [8.9360483e-09 9.9971420e-01 6.2249042e-06 ... 1.7531687e-05
#   1.8806271e-04 2.2864145e-07]
#  ...
#  [6.1757049e-10 1.5859261e-07 1.4849565e-10 ... 3.6621930e-06
#   5.4272641e-07 6.1109849e-06]
#  [1.9460324e-09 7.1454562e-09 5.3209329e-12 ... 3.7532515e-09
#   7.6431263e-04 3.5935919e-09]
#  [1.7010688e-09 3.8913797e-09 1.4859075e-09 ... 6.3931187e-12
#   1.3913987e-10 9.1058853e-12]]

# %%
import numpy as np
#print(np.argmax(predections[0]))

# %%
#

# %%
import cv2 as cv
x=0
for i in range(10):
    print(x)
    img=cv.imread(str(x)+".jpg",cv.IMREAD_GRAYSCALE)
    plt.imshow(img,cmap=plt.cm.binary)
    plt.show()
    x+=1
    img=cv.resize(img,(28,28))
    predections=model.predict([img])
    print(np.argmax(predections[0]))
# Out:
# 0
# 6
# 1
# 6
# 2
# 6
# 3
# 6
# 4
# 5
# 5
# 6
# 6
# 6
# 7
# 6
# 8
# 6
# 9
# 6

# %%
# Out:
# 3

# %%
# Out:
# numpy.ndarray
